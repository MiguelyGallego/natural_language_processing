# %%
# !pip install num2words
# Out:
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (0.5.12)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words) (0.6.2)

# %%
import pandas as pd
import numpy as np
import unicodedata
import nltk
from nltk import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from num2words import num2words

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv('binomial_data.csv')
print(len(df))
df.head()
# Out:
# 40000
#    overall                                         reviewText  overall_label
# 0      1.0  Deepak Chopra would like to introduce you to J...              1
# 1      1.0  this games sucks. spend your time on somthing ...              1
# 2      1.0  Don't waste your money. Nothing here you can't...              1
# 3      1.0  How I wish Amazon would make their own content...              1
# 4      1.0  Moderately interesting plot, but extremely poo...              1

# %%
def nltk_cleaner(text, tokenizer, sw_list, lemmatizer):
    """
    Limpia y normaliza un texto utilizando una serie de pasos de procesamiento:

    Parámetros:
    - text (str): El texto a limpiar y normalizar.
    - tokenizer: Un objeto tokenizer para separar palabras y eliminar signos de puntuación.
    - sw_list: Una lista de palabras de parada (stop words) que se deben eliminar del texto.
    - lemmatizer: Un lematizador para reducir las palabras a su forma base.

    Retorna:
    - str: El texto limpio y normalizado.
    """

    clean_text = list()

    # Eliminar acentos, etc
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')

    # Separar palabras eliminando signos de puntuación
    for word in tokenizer.tokenize(text):

        # Eliminar stop words
        if word not in sw_list:

        # Eliminar espacios sobrantes, convertir a minúsculas y lematizar
            clean_word = lemmatizer.lemmatize(word).lower().strip()

        # Convertir dígitos a palabras
            if clean_word.isdigit():
                clean_word = num2words(clean_word, lang='en')

            clean_text.append(clean_word)

    return ' '.join(clean_text)

# %%
# Se define un tokenizador, una lista de palabras de parada y un lematizador que serán utilizados en el proceso de limpieza y normalización de texto
tokenizer = RegexpTokenizer(r'\w+')
sw_list = stopwords.words('english')
lemmatizer = WordNetLemmatizer()

# %%
# Se pasan todos los caracteres a str y se llama a la función de limpieza
df['reviewText'] = df['reviewText'].astype(str)
processed_reviews = df['reviewText'].apply(nltk_cleaner, tokenizer=tokenizer, sw_list=sw_list, lemmatizer=lemmatizer)

# %%
print('Review original: {}'.format(df['reviewText'].values[0]))
print('Review procesada: {}'.format(processed_reviews[0]))
# Out:
# Review original: Deepak Chopra would like to introduce you to Jesus. Not the Jesus you might know from Sunday School, or the pulpit, or from conversations with Christian friends. Chopra has in mind a different Jesus, one who embodied the highest level of enlightenment and invites his followers into union with God and indeed with all Creation. He calls his book after his name for this character: "The Third Jesus."
#
# A practicing Christian might well object to this premise on doctrinal grounds, but you don't have to be Christian to be wary of this book. I would argue that Chopra fails, and fails repeatedly, on a more fundamental level than orthodoxy. The title of the book is a signal example. Early on, Chopra explains that there are three Jesuses: one is the historical Jesus, about whom, Chopra says, we know next to nothing. The second Jesus is the one built up by the Church for worship, including theologizing about the Trinity and the Holy Spirit. Chopras Third Jesus is the Jesus who taught his followers how to reach God-consciousness.
#
# But at this point, Chopra has already avowed that we know little or nothing about the historical Jesus. And if we are not talking about the Jesus of history, then we are by definition talking about a made-up Jesus. There is no third Jesus; if we have no historical ground to stand on, then Chopras Christ has no more claim to authenticity than the one promoted by the Church.
#
# Similar problems afflict Chopras methodology; specifically, he doesnt seem to have one. At times he evinces a deep skepticism about our ability to trust the canonical gospel texts, tainted as they are (in his view) by the agendas of their authors. Then again, dozens of pages in the middle portion of the book are taken up by a catalogue of important gospel passages (as screened, of course, through Chopras interpretations). What makes these selections a window onto Jesus teachings and not just more of the flotsam of overeager evangelists? Chopra never says, although he periodically states that he can really feel Jesus truth shining through in one passage or another.
#
# It might be possible to wink at all of this if Chopra were giving useful advice, but he doesnt even seem to have a clear grasp of what spiritual principles he wants to communicate to the reader. He suggests Jesus was fully enlightened, so that his thoughts and the thoughts of God were one and the same, a state he calls God-consciousness. (Every mention of light in the New Testament is taken to refer to this state. Why? Who knows?) What precisely Chopra means by God is not clear: at times he seems to be referring to an entity as is familiar in the Judeo-Christian tradition; at others, a mystical force; and at least once, God is described as pure awareness. The end goal for those on the spiritual path appears to be total union with God (whatever God is), and the annihilation of the dualistic worldview in which there is I and you, good and evil, not-God and God.
#
# In this, Chopra appears to be drawing heavily on Hinduism, with a splash of Buddhism for taste. There is nothing wrong with Hinduism, and nothing wrong with readers or practitioners who would like to pursue Hinduism, but if that is your aim, I can only think you would be better off reading (say) the Bhagavad-Gita than getting quasi-Hindu concepts filtered through and then foisted on the holy text of a completely different religion. Even if only implicitly, Chopra seems to be viewing one tradition through the lens of another, and in doing so distorts them both.
#
# Theology is arbitrary, writes Chopra; it can find any story it wants, any hidden meaning. Once you take a completely mystical view of Jesus, you are exempt from proof. He might as well be talking about his own book. Chopra seems to think he has found some kind of middle way between historical Jesus and religious Christ, yet with no evident grounding other than his own copious assumptions, we have no reason to take him seriously, even if we don't have any specifically Christian qualms about his program. Quite contrary to his subtitle, this is a Christ we can safely ignore.
#
# ~
# Review procesada: deepak chopra would like introduce jesus not jesus might know sunday school pulpit conversation christian friend chopra mind different jesus one embodied highest level enlightenment invite follower union god indeed creation he call book name character the third jesus a practicing christian might well object premise doctrinal ground christian wary book i would argue chopra fails fails repeatedly fundamental level orthodoxy the title book signal example early chopra explains three jesuses one historical jesus chopra say know next nothing the second jesus one built church worship including theologizing trinity holy spirit chopras third jesus jesus taught follower reach god consciousness but point chopra already avowed know little nothing historical jesus and talking jesus history definition talking made jesus there third jesus historical ground stand chopras christ claim authenticity one promoted church similar problem afflict chopras methodology specifically doesnt seem one at time evinces deep skepticism ability trust canonical gospel text tainted view agenda author then dozen page middle portion book taken catalogue important gospel passage screened course chopras interpretation what make selection window onto jesus teaching flotsam overeager evangelist chopra never say although periodically state really feel jesus truth shining one passage another it might possible wink chopra giving useful advice doesnt even seem clear grasp spiritual principle want communicate reader he suggests jesus fully enlightened thought thought god one state call god consciousness every mention light new testament taken refer state why who know what precisely chopra mean god clear time seems referring entity familiar judeo christian tradition others mystical force least god described pure awareness the end goal spiritual path appears total union god whatever god annihilation dualistic worldview i good evil god god in chopra appears drawing heavily hinduism splash buddhism taste there nothing wrong hinduism nothing wrong reader practitioner would like pursue hinduism aim i think would better reading say bhagavad gita getting quasi hindu concept filtered foisted holy text completely different religion even implicitly chopra seems viewing one tradition lens another distorts theology arbitrary writes chopra find story want hidden meaning once take completely mystical view jesus exempt proof he might well talking book chopra seems think found kind middle way historical jesus religious christ yet evident grounding copious assumption reason take seriously even specifically christian qualm program quite contrary subtitle christ safely ignore

# %%
# Se añade la fila de reviews procesadas al df
df.loc[:, 'processedReview'] = processed_reviews

# %%
# Se sustituyen las columnas vacias por NaN
df['processedReview'] = df['processedReview'].replace('', np.nan)

# Se elimina los valores NaN de la columna
df = df.dropna(subset=['processedReview'])

# %%
print(len(df))
df.head()

# A pesaar de los NaN que se eliminan, no son suficientes para desvalancear el dataset
# Out:
# 39983
#    overall                                         reviewText  overall_label  \
# 0      1.0  Deepak Chopra would like to introduce you to J...              1
# 1      1.0  this games sucks. spend your time on somthing ...              1
# 2      1.0  Don't waste your money. Nothing here you can't...              1
# 3      1.0  How I wish Amazon would make their own content...              1
# 4      1.0  Moderately interesting plot, but extremely poo...              1
#
#                                      processedReview
# 0  deepak chopra would like introduce jesus not j...
# 1  game suck spend time somthing else dont buy do...
# 2  don waste money nothing get free listening rai...
# 3  how i wish amazon would make content compatibl...
# 4  moderately interesting plot extremely poor cop...

# %%
# Guardar el DataFrame preprocesados en un archivo CSV
df.to_csv('preprocessing_data.csv', index=False)

# %%
# Se comprueba que se ha guardado correctamente
df = pd.read_csv('preprocessing_data.csv')

print(len(df))
df.head()
# Out:
# 39983
#    overall                                         reviewText  overall_label  \
# 0      1.0  Deepak Chopra would like to introduce you to J...              1
# 1      1.0  this games sucks. spend your time on somthing ...              1
# 2      1.0  Don't waste your money. Nothing here you can't...              1
# 3      1.0  How I wish Amazon would make their own content...              1
# 4      1.0  Moderately interesting plot, but extremely poo...              1
#
#                                      processedReview
# 0  deepak chopra would like introduce jesus not j...
# 1  game suck spend time somthing else dont buy do...
# 2  don waste money nothing get free listening rai...
# 3  how i wish amazon would make content compatibl...
# 4  moderately interesting plot extremely poor cop...
